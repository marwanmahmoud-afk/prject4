# %% [markdown]
# ### after downloading data file
# i move it in desktop(directory) and open it in vs code

# %%
import numpy as np 
import pandas as pd 
filename = 'data.csv'
data1 = pd.read_csv(filename)
data1
# Out:
#                  name              city    salary  \
# 0     Mohamed Youssef            Assiut  113181.0
# 1          Mariam Ali  Shubra El Kheima       NaN
# 2          Amir Salem        Alexandria   10996.0
# 3     Mohsen El-Bakry              Suez       NaN
# 4          Amir Osman           Zagazig       NaN
# ...               ...               ...       ...
# 2495    Magdy Ramadan        Alexandria   70199.0
# 2496   Kamal Mahmoudi        Alexandria   11374.0
# 2497     Nermine Saad        Alexandria   57022.0
# 2498   Wafaa El-Gabry          Mansoura   33862.0
# 2499       Nadia Nour             Aswan   32823.0
#
#                                         education  age socialtype  year
# 0                                 Tourism Studies   25    Married  2019
# 1     Computer Science and Information Technology   34   Divorced  2019
# 2                 Economics and Political Science   30    Married  2019
# 3                                    Architecture   40   Divorced  2019
# ...

# %% [markdown]
# now we gonna capitalize column name

# %% [markdown]
# ## firstly we gonna take a copy

# %%
df = data1.copy()
df
# Out:
#                  name              city    salary  \
# 0     Mohamed Youssef            Assiut  113181.0
# 1          Mariam Ali  Shubra El Kheima       NaN
# 2          Amir Salem        Alexandria   10996.0
# 3     Mohsen El-Bakry              Suez       NaN
# 4          Amir Osman           Zagazig       NaN
# ...               ...               ...       ...
# 2495    Magdy Ramadan        Alexandria   70199.0
# 2496   Kamal Mahmoudi        Alexandria   11374.0
# 2497     Nermine Saad        Alexandria   57022.0
# 2498   Wafaa El-Gabry          Mansoura   33862.0
# 2499       Nadia Nour             Aswan   32823.0
#
#                                         education  age socialtype  year
# 0                                 Tourism Studies   25    Married  2019
# 1     Computer Science and Information Technology   34   Divorced  2019
# 2                 Economics and Political Science   30    Married  2019
# 3                                    Architecture   40   Divorced  2019
# ...

# %% [markdown]
# #  (capitalizing name row)

# %%
df.rename(columns={'name' : 'NAME'},inplace=True)
df
# Out:
#                  NAME              city    salary  \
# 0     Mohamed Youssef            Assiut  113181.0
# 1          Mariam Ali  Shubra El Kheima       NaN
# 2          Amir Salem        Alexandria   10996.0
# 3     Mohsen El-Bakry              Suez       NaN
# 4          Amir Osman           Zagazig       NaN
# ...               ...               ...       ...
# 2495    Magdy Ramadan        Alexandria   70199.0
# 2496   Kamal Mahmoudi        Alexandria   11374.0
# 2497     Nermine Saad        Alexandria   57022.0
# 2498   Wafaa El-Gabry          Mansoura   33862.0
# 2499       Nadia Nour             Aswan   32823.0
#
#                                         education  age socialtype  year
# 0                                 Tourism Studies   25    Married  2019
# 1     Computer Science and Information Technology   34   Divorced  2019
# 2                 Economics and Political Science   30    Married  2019
# 3                                    Architecture   40   Divorced  2019
# ...

# %% [markdown]
# #  (changing socialtype row)

# %%
df.rename(columns={'socialtype' : 'MATREAL_STATUS'},inplace=True)
df
# Out:
#                  NAME              city    salary  \
# 0     Mohamed Youssef            Assiut  113181.0
# 1          Mariam Ali  Shubra El Kheima       NaN
# 2          Amir Salem        Alexandria   10996.0
# 3     Mohsen El-Bakry              Suez       NaN
# 4          Amir Osman           Zagazig       NaN
# ...               ...               ...       ...
# 2495    Magdy Ramadan        Alexandria   70199.0
# 2496   Kamal Mahmoudi        Alexandria   11374.0
# 2497     Nermine Saad        Alexandria   57022.0
# 2498   Wafaa El-Gabry          Mansoura   33862.0
# 2499       Nadia Nour             Aswan   32823.0
#
#                                         education  age MATREAL_STATUS  year
# 0                                 Tourism Studies   25        Married  2019
# 1     Computer Science and Information Technology   34       Divorced  2019
# 2                 Economics and Political Science   30        Married  2019
# ...

# %% [markdown]
# # 9 the relation
# the releation that all divorced has null salary

# %%
df = data1

# %%
df[df['salary'].isnull()]
# Out:
#                 name              city  salary  \
# 1         Mariam Ali  Shubra El Kheima     NaN
# 3    Mohsen El-Bakry              Suez     NaN
# 4         Amir Osman           Zagazig     NaN
# 5         Nadia Amin         Port Said     NaN
# 8    Mervat El-Sayed              Suez     NaN
# ..               ...               ...     ...
# 865  Khaled Mohammed             Aswan     NaN
# 879  Salma Abdelaziz           Zagazig     NaN
# 881    Khaled El-Din             Tanta     NaN
# 883       Mohsen Ali             Luxor     NaN
# 886     Kamal El-Din          Mansoura     NaN
#
#                                        education  age socialtype  year
# 1    Computer Science and Information Technology   34   Divorced  2019
# 3                                   Architecture   40   Divorced  2019
# 4                                      Education   53   Divorced  2019
# 5                                       Pharmacy   26   Divorced  2019
# ...

# %% [markdown]
# #

# %% [markdown]
# ### now we gonna make a full analysis

# %% [markdown]
# #### firstly : number on nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   object
#  1   city            2463 non-null   object
#  2   salary          2286 non-null   float64
#  3   education       2475 non-null   object
#  4   age             2500 non-null   int64
#  5   MATREAL_STATUS  2500 non-null   object
#  6   year            2500 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 136.8+ KB

# %% [markdown]
# we have 2500 column x 7rows
# (so there's 37 null in city row ,
# and 214 null in salary row ,
# and 25 null in education row)

# %% [markdown]
# # Summary statistics for numerical columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   object
#  1   city            2463 non-null   object
#  2   salary          2286 non-null   float64
#  3   education       2475 non-null   object
#  4   age             2500 non-null   int64
#  5   MATREAL_STATUS  2500 non-null   object
#  6   year            2500 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 136.8+ KB

# %% [markdown]
# ## detecting the outliers

# %%
import seaborn as sns 
y = sns.boxplot(df['salary'])
# Out:
# c:\Users\ACER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## due to the presence of dots
# ### there's outliers

# %%
import seaborn as sns 
y = sns.boxplot(df['year'])
# Out:
# c:\Users\ACER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## there's no outliers

# %% [markdown]
# # 8 (changing columns into suitable type)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   object
#  1   city            2463 non-null   object
#  2   salary          2286 non-null   float64
#  3   education       2475 non-null   object
#  4   age             2500 non-null   int64
#  5   MATREAL_STATUS  2500 non-null   object
#  6   year            2500 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 136.8+ KB

# %%
df['age'] = df['age'].astype('category') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   object
#  1   city            2463 non-null   object
#  2   salary          2286 non-null   float64
#  3   education       2475 non-null   object
#  4   age             2500 non-null   category
#  5   MATREAL_STATUS  2500 non-null   object
#  6   year            2500 non-null   int64
# dtypes: category(1), float64(1), int64(1), object(4)
# memory usage: 121.1+ KB

# %%
df['MATREAL_STATUS'] = df['MATREAL_STATUS'].astype('category') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   object
#  1   city            2463 non-null   object
#  2   salary          2286 non-null   float64
#  3   education       2475 non-null   object
#  4   age             2500 non-null   category
#  5   MATREAL_STATUS  2500 non-null   category
#  6   year            2500 non-null   int64
# dtypes: category(2), float64(1), int64(1), object(3)
# memory usage: 104.2+ KB

# %%
df['NAME'] = df['NAME'].astype('string') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   string
#  1   city            2463 non-null   object
#  2   salary          2286 non-null   float64
#  3   education       2475 non-null   object
#  4   age             2500 non-null   category
#  5   MATREAL_STATUS  2500 non-null   category
#  6   year            2500 non-null   int64
# dtypes: category(2), float64(1), int64(1), object(2), string(1)
# memory usage: 104.2+ KB

# %%
df['city'] = df['city'].astype('string') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   string
#  1   city            2463 non-null   string
#  2   salary          2286 non-null   float64
#  3   education       2475 non-null   object
#  4   age             2500 non-null   category
#  5   MATREAL_STATUS  2500 non-null   category
#  6   year            2500 non-null   int64
# dtypes: category(2), float64(1), int64(1), object(1), string(2)
# memory usage: 104.2+ KB

# %%
df['education'] = df['education'].astype('string') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   string
#  1   city            2463 non-null   string
#  2   salary          2286 non-null   float64
#  3   education       2475 non-null   string
#  4   age             2500 non-null   category
#  5   MATREAL_STATUS  2500 non-null   category
#  6   year            2500 non-null   int64
# dtypes: category(2), float64(1), int64(1), string(3)
# memory usage: 104.2 KB

# %% [markdown]
# ### we gonna fix the nulls with suitable values

# %%
 df.fillna(df.mean(),inplace=True)
 df
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_10668/3986496417.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#                  NAME              city         salary  \
# 0     Mohamed Youssef            Assiut  113181.000000
# 1          Mariam Ali  Shubra El Kheima   92922.731409
# 2          Amir Salem        Alexandria   10996.000000
# 3     Mohsen El-Bakry              Suez   92922.731409
# 4          Amir Osman           Zagazig   92922.731409
# ...               ...               ...            ...
# 2495    Magdy Ramadan        Alexandria   70199.000000
# 2496   Kamal Mahmoudi        Alexandria   11374.000000
# 2497     Nermine Saad        Alexandria   57022.000000
# 2498   Wafaa El-Gabry          Mansoura   33862.000000
# ...

# %% [markdown]
# now we gonna fill nulls in education (null = no data)

# %%
df['education'].fillna('no data' , inplace=True)
df
# Out:
#                  NAME              city         salary  \
# 0     Mohamed Youssef            Assiut  113181.000000
# 1          Mariam Ali  Shubra El Kheima   92922.731409
# 2          Amir Salem        Alexandria   10996.000000
# 3     Mohsen El-Bakry              Suez   92922.731409
# 4          Amir Osman           Zagazig   92922.731409
# ...               ...               ...            ...
# 2495    Magdy Ramadan        Alexandria   70199.000000
# 2496   Kamal Mahmoudi        Alexandria   11374.000000
# 2497     Nermine Saad        Alexandria   57022.000000
# 2498   Wafaa El-Gabry          Mansoura   33862.000000
# 2499       Nadia Nour             Aswan   32823.000000
#
#                                         education age MATREAL_STATUS  year
# 0                                 Tourism Studies  25        Married  2019
# 1     Computer Science and Information Technology  34       Divorced  2019
# 2                 Economics and Political Science  30        Married  2019
# ...

# %% [markdown]
# as we can see there's no nulls in education column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   string
#  1   city            2463 non-null   string
#  2   salary          2500 non-null   float64
#  3   education       2500 non-null   string
#  4   age             2500 non-null   category
#  5   MATREAL_STATUS  2500 non-null   category
#  6   year            2500 non-null   int64
# dtypes: category(2), float64(1), int64(1), string(3)
# memory usage: 104.2 KB

# %%
df['city'].fillna('no data' , inplace=True)
df
# Out:
#                  NAME              city         salary  \
# 0     Mohamed Youssef            Assiut  113181.000000
# 1          Mariam Ali  Shubra El Kheima   92922.731409
# 2          Amir Salem        Alexandria   10996.000000
# 3     Mohsen El-Bakry              Suez   92922.731409
# 4          Amir Osman           Zagazig   92922.731409
# ...               ...               ...            ...
# 2495    Magdy Ramadan        Alexandria   70199.000000
# 2496   Kamal Mahmoudi        Alexandria   11374.000000
# 2497     Nermine Saad        Alexandria   57022.000000
# 2498   Wafaa El-Gabry          Mansoura   33862.000000
# 2499       Nadia Nour             Aswan   32823.000000
#
#                                         education age MATREAL_STATUS  year
# 0                                 Tourism Studies  25        Married  2019
# 1     Computer Science and Information Technology  34       Divorced  2019
# 2                 Economics and Political Science  30        Married  2019
# ...

# %% [markdown]
# now there's no nulls in df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            2500 non-null   string
#  1   city            2500 non-null   string
#  2   salary          2500 non-null   float64
#  3   education       2500 non-null   string
#  4   age             2500 non-null   category
#  5   MATREAL_STATUS  2500 non-null   category
#  6   year            2500 non-null   int64
# dtypes: category(2), float64(1), int64(1), string(3)
# memory usage: 104.2 KB

# %%
 df['salary'].isnull
# Out:
# <bound method Series.isnull of 0       113181.000000
# 1        92922.731409
# 2        10996.000000
# 3        92922.731409
# 4        92922.731409
#             ...
# 2495     70199.000000
# 2496     11374.000000
# 2497     57022.000000
# 2498     33862.000000
# 2499     32823.000000
# Name: salary, Length: 2500, dtype: float64>

# %% [markdown]
# ## 15

# %% [markdown]
# by using .value_counts we realize that the most educated in df is (Public Relations and Advertising  by 143)

# %%
df['education'].value_counts(dropna=False)
# Out:
# Public Relations and Advertising               143
# Commerce                                       141
# Agriculture                                    140
# Architecture                                   135
# Civil Aviation                                 134
# Economics and Political Science                134
# Tourism Studies                                130
# Fine Arts                                      129
# Applied Sciences                               125
# Education                                      123
# Nursing                                        121
# Computer Science and Information Technology    119
# Science                                        117
# Psychology                                     117
# Law                                            115
# Environmental Agriculture                      114
# Medicine                                       113
# Pharmacy                                       110
# ...

# %% [markdown]
# # The average salaries by year

# %%
 print(df.groupby('year').agg({'salary':'mean'}))
# Out:
#              salary
# year
# 2019  155900.744713
# 2020   77721.883097
# 2021   76354.662890
# 2022   76551.691489
# 2023   56219.714286

# %% [markdown]
# # The average salaries by city

# %%
 print(df.groupby('city').agg({'salary':'mean'}))
# Out:
#                          salary
# city
# Alexandria         77591.942349
# Assiut             70028.243867
# Aswan             186620.122544
# Asyut              74682.370223
# Beni Suef          75105.584284
# Cairo              77226.320543
# Damietta           77967.687305
# Giza               83132.529115
# Ismailia           88002.534259
# Kafr El Sheikh     78532.916581
# Luxor             133463.674024
# Mansoura           89903.717229
# Minya             114906.670166
# Port Said          72467.486072
# Qena               73723.398584
# Shubra El Kheima   76830.313558
# Sohag              81894.768275
# Suez              177175.219301
# Tanta              78603.787517
# Zagazig            78155.988699
# no data            70051.369109

# %% [markdown]
# # the most city in salaries

# %%
x= df.groupby(['city'])['salary'].max()
x.head(1)
# Out:
# city
# Alexandria    148179.0
# Name: salary, dtype: float64

# %% [markdown]
# # the most educated in this city

# %%
y=df.groupby(['city'])['education'].max()
y.head(1)
# Out:
# city
# Alexandria    Tourism Studies
# Name: education, dtype: string

# %% [markdown]
# # now we gonna create paivot table with city and year

# %%
df.pivot_table(index='year',
              
               columns=['city'],
               aggfunc='count')
# Out:
#      MATREAL_STATUS                                                    \
# city     Alexandria Assiut Aswan Asyut Beni Suef Cairo Damietta  Giza
# year
# 2019           29.0   23.0  26.0  31.0      24.0  22.0     22.0  29.0
# 2020           20.0   33.0  23.0  28.0      26.0  23.0     24.0  25.0
# 2021           19.0   13.0  20.0  27.0      15.0  16.0     20.0  17.0
# 2022           53.0   58.0  48.0  47.0      50.0  62.0     56.0  60.0
# 2023            3.0    NaN   2.0   NaN       1.0   3.0      NaN   NaN
#
#                               ...   salary                        \
# city Ismailia Kafr El Sheikh  ... Mansoura Minya Port Said  Qena
# year                          ...
# 2019     25.0           21.0  ...     24.0  18.0      35.0  19.0
# 2020     20.0           19.0  ...     27.0  18.0      17.0  28.0
# 2021     15.0           17.0  ...     20.0  17.0      20.0   8.0
# 2022     57.0           55.0  ...     58.0  58.0      71.0  50.0
# ...

# %% [markdown]
# # corr. between salary and year

# %%
df.corr()
# Out:
#           salary      year
# salary  1.000000 -0.062662
# year   -0.062662  1.000000

# %% [markdown]
# # bonus

# %%
row1 = {'year' : 2019 , 'GDP' :1.2 }
row2 = {'year' :  2020, 'GDP' : 2.1}
row3 = {'year' :  2021, 'GDP' : 3}
row4 = {'year' :  2022, 'GDP' : 2.5}
row5 = {'year' :  2023, 'GDP' : 4}
df2 = pd.DataFrame([row1,row2,row3,row4,row5])
df2
# Out:
#    year  GDP
# 0  2019  1.2
# 1  2020  2.1
# 2  2021  3.0
# 3  2022  2.5
# 4  2023  4.0

# %%
df
# Out:
#                  NAME              city         salary  \
# 0     Mohamed Youssef            Assiut  113181.000000
# 1          Mariam Ali  Shubra El Kheima   92922.731409
# 2          Amir Salem        Alexandria   10996.000000
# 3     Mohsen El-Bakry              Suez   92922.731409
# 4          Amir Osman           Zagazig   92922.731409
# ...               ...               ...            ...
# 2495    Magdy Ramadan        Alexandria   70199.000000
# 2496   Kamal Mahmoudi        Alexandria   11374.000000
# 2497     Nermine Saad        Alexandria   57022.000000
# 2498   Wafaa El-Gabry          Mansoura   33862.000000
# 2499       Nadia Nour             Aswan   32823.000000
#
#                                         education age MATREAL_STATUS  year
# 0                                 Tourism Studies  25        Married  2019
# 1     Computer Science and Information Technology  34       Divorced  2019
# 2                 Economics and Political Science  30        Married  2019
# ...

# %% [markdown]
# # merging data

# %%
z= df.merge(df2,how='inner',on='year')
z
# Out:
#                  name              city    salary  \
# 0     Mohamed Youssef            Assiut  113181.0
# 1          Mariam Ali  Shubra El Kheima       NaN
# 2          Amir Salem        Alexandria   10996.0
# 3     Mohsen El-Bakry              Suez       NaN
# 4          Amir Osman           Zagazig       NaN
# ...               ...               ...       ...
# 2495    Magdy Ramadan        Alexandria   70199.0
# 2496   Kamal Mahmoudi        Alexandria   11374.0
# 2497     Nermine Saad        Alexandria   57022.0
# 2498   Wafaa El-Gabry          Mansoura   33862.0
# 2499       Nadia Nour             Aswan   32823.0
#
#                                         education  age socialtype  year  GDP
# 0                                 Tourism Studies   25    Married  2019  1.2
# 1     Computer Science and Information Technology   34   Divorced  2019  1.2
# 2                 Economics and Political Science   30    Married  2019  1.2
# ...

# %% [markdown]
# # rows 2500

# %% [markdown]
# exporting data

# %%
z.to_csv('merged.csv')
